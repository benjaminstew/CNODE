# %%
import sys
sys.path.insert(0, "..") # add parent CNODE package to sys.path

import numpy as np
import matplotlib.pyplot as plt
from src.data.vdpo_loader import create_vdpo_dataset
from src.models.node_pyomo_base import NODEPyomo

# %% [markdown]
# ## 1. Create dataset of VDPO state vectors

# %%
train_interpol, test_interpol, full_grid, Y_true, train_grid, Y_obs, Y_smooth, test_grid, Y_test = create_vdpo_dataset(num_nodes=400, end_time=30, noise_sd=0.1)

# Print dataset shapes and summary stats 
print(f"Full grid shape: {full_grid.shape}")
print(f"Train grid shape: {train_grid.shape}")
print(f"Test grid shape: {test_grid.shape}")
print(f"Y_true shape: {Y_true.shape}")
print(f"Y_obs shape: {Y_obs.shape}")
print(f"Y_obs displacement average value: {np.mean(Y_obs[:, 0]):.2f}")
print(f"Y_obs velocity average value: {np.mean(Y_obs[:, 1]):.2f}")
print(f"Y_obs displacement range: [{Y_obs[:, 0].min():.2f}, {Y_obs[:, 0].max():.2f}]")
print(f"Y_obs velocity range: [{Y_obs[:, 1].min():.2f}, {Y_obs[:, 1].max():.2f}]")

# Visualise trajectories from train and test datasets 
plt.figure(figsize=(15, 8))
plt.scatter(train_grid, Y_obs[:, 0], color='blue', marker='o', s=10, label="Disp Train ")
plt.scatter(test_grid, Y_test[:, 0], color='green', marker='o', s=10, label="Disp Test")
plt.scatter(train_grid, Y_obs[:, 1], color='orange', marker='o', s=10, label="Vel Train ")
plt.scatter(test_grid, Y_test[:, 1], color='red', marker='o', s=10, label="Vel Test")
plt.xlabel('time')
plt.ylabel('y (state)')
plt.legend()
# Out:
# Full grid shape: (399,)
# Train grid shape: (200,)
# Test grid shape: (200,)
# Y_true shape: (399, 2)
# Y_obs shape: (200, 2)
# Y_obs displacement average value: 0.46
# Y_obs velocity average value: 0.25
# Y_obs displacement range: [-2.48, 2.57]
# Y_obs velocity range: [-3.87, 3.86]

# %% [markdown]
# ## 2. Optimise pyomo model using IPOPT (DC and IRR-DC methods)

# %%
T = train_grid[-1] - train_grid[0]
layer_sizes = [2, 32, 2] 
num_res_eval_nodes = 50

solver_options_dc = {
    "max_iter": 500,
    "nlp_scaling_method": "gradient-based",
    "mu_strategy": "adaptive",
    "tol": 1e-6,
    "acceptable_tol": 1e-5,
    "acceptable_iter": 10
}

pyo_model_dc = NeuralODEPyomo(
    Y_obs, layer_sizes, T, 
    state_lower_bound=-100,
    state_upper_bound=100,
    param_lower_bound=-100,
    param_upper_bound=100,
    lambda_reg=1e-4, 
    Y_smooth=Y_smooth, 
    transcription_method='dc'
)
pyo_model_dc.solve_model(solver_options_dc)
# Out:
# Solver available?: True
# Ipopt 3.14.19: max_iter=500
# nlp_scaling_method=gradient-based
# mu_strategy=adaptive
# print_level=5
# tol=1e-06
# acceptable_tol=1e-05
# acceptable_iter=10
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.19, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:   131342
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    64729
#
# Total number of variables............................:      562
#                      variables with only lower bounds:        0
# ...

# %%
solver_options_irrdc = {''
    "max_iter": 1000,
    "nlp_scaling_method": "gradient-based",
    "mu_strategy": "adaptive",
    "tol": 1e-6,
    "acceptable_tol": 1e-5,
    "acceptable_iter": 10
} 

pyo_model_irrdc = NeuralODEPyomo(
    Y_obs, layer_sizes, T, 
    state_lower_bound=-100,
    state_upper_bound=100,
    param_lower_bound=-100,
    param_upper_bound=100,
    lambda_reg=1e-4, 
    Y_smooth=Y_smooth, 
    transcription_method='irrdc',
    rho_reg=5,
    num_res_eval_nodes=num_res_eval_nodes
)
pyo_model_irrdc.solve_model(solver_options_irrdc)
# Out:
# Number of node clashes between res eval grid and colloc grid: 2 of 50 res eval nodes.
# Solver available?: True
# Ipopt 3.14.19: max_iter=1000
# nlp_scaling_method=gradient-based
# mu_strategy=adaptive
# print_level=5
# tol=1e-06
# acceptable_tol=1e-05
# acceptable_iter=10
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.19, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:   131342
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   157114
#
# ...

# %% [markdown]
# ## 3. Use the trained model as RHS of an ODE system

# %%
y0_train = Y_obs[0, :]
y0_test = Y_test[0, :]

predicted_trajectory_train_irrdc = pyo_model_irrdc.get_predicted_trajectory(y0_train, train_grid, rtol=1e-7, atol=1e-9, max_step=(train_grid[1]-train_grid[0]))
predicted_trajectory_test_irrdc = pyo_model_irrdc.get_predicted_trajectory(y0_test, test_grid, rtol=1e-7, atol=1e-9, max_step=(test_grid[1]-test_grid[0]))

predicted_trajectory_train_dc = pyo_model_dc.get_predicted_trajectory(y0_train, train_grid, rtol=1e-7, atol=1e-9, max_step=(train_grid[1]-train_grid[0]))
predicted_trajectory_test_dc = pyo_model_dc.get_predicted_trajectory(y0_test, test_grid, rtol=1e-7, atol=1e-9, max_step=(test_grid[1]-test_grid[0]))

# %% [markdown]
# ## 4. Plot predicted trajectories over train and test domains

# %%
plt.figure(figsize=(15, 8))

# Plot true trajectory (dotted blue)
plt.plot(full_grid, Y_true[:, 0], color='darkblue', linestyle=':', linewidth=2, alpha=0.7, label="True Data")
plt.plot(full_grid, Y_true[:, 1], color='darkblue', linestyle=':', linewidth=2, alpha=0.7)

# Plot noisy training data (orange dots)
plt.scatter(train_grid, Y_obs[:, 0], color='darkorange', marker='o', s=30, alpha=0.7, label="Noisy Data")
plt.scatter(train_grid, Y_obs[:, 1], color='darkorange', marker='o', s=30, alpha=0.7)

# plot predicted trajectories (train and test for both dc and iirdc)
plt.plot(train_grid, predicted_trajectory_train_irrdc[:, 0], color='forestgreen', label="Predicted Trajectory (IRR-DC)")
plt.plot(train_grid, predicted_trajectory_train_irrdc[:, 1], color='forestgreen')
plt.plot(test_grid, predicted_trajectory_test_irrdc[:, 0], color='forestgreen')
plt.plot(test_grid, predicted_trajectory_test_irrdc[:, 1], color='forestgreen')

plt.plot(train_grid, predicted_trajectory_train_dc[:, 0], color='firebrick', label="Predicted Trajectory (DC)")
plt.plot(train_grid, predicted_trajectory_train_dc[:, 1], color='firebrick')
plt.plot(test_grid, predicted_trajectory_test_dc[:, 0], color='firebrick')   
plt.plot(test_grid, predicted_trajectory_test_dc[:, 1], color='firebrick')

# plot optimised Y_star values at collocation nodes
'''plt.plot(train_grid, Y_star_values[:, 0], 'g-.', linewidth=1, label="$Y_*$ disp")
plt.plot(train_grid, Y_star_values[:, 1], 'r-.', linewidth=1, label="$Y_*$ vel")'''

# Set axis labels and ticks font size
label_fontsize = 24
tick_fontsize = 21
plt.xlabel('Time (t)', fontsize=label_fontsize)
plt.ylabel('State Values: u(t), v(t)', fontsize=label_fontsize)
plt.yticks([-4, -2, 0, 2, 4], fontsize=tick_fontsize)
plt.xticks([0, 5, 10, 15, 20, 25, 30], fontsize=tick_fontsize)
# Add dashed light grey translucent grid
plt.grid(True, which='both', axis='both', linestyle='--', color='lightgrey', alpha=0.8)
# Custom legend below x-axis, no box, horizontal labels, reduced font size for fit
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, frameon=False, fontsize=20)

# %% [markdown]
# ## 5. Plot ODE residual in training domain

# %%
from src.direct_collocation import BarycentricInterpolation
from matplotlib.patches import Rectangle, ConnectionPatch

#--------------------------RESIDUAL COMPUTATION FUNCS-----------------------------

def compute_continuous_residual(pyo_model, num_eval_nodes):
    """
    Compute r(t) = dY*/dt - NN(Y*(t)) on a dense equidistant grid by
    barycentric interpolation/differentiation of the trained collocation solution.
    Works for both 'dc' and 'irrdc' models.
    Returns: t_eval (num_eval_nodes,), residual (num_eval_nodes, state_dim)
    """
    N = pyo_model.num_colloc_nodes
    bary = BarycentricInterpolation(
        0, pyo_model.end_time, N,
        transcription_method='irrdc',
        num_res_eval_nodes=num_eval_nodes
    )
    L = bary.L_res          # (num_eval_nodes, N)
    D = bary.D_res          # (num_eval_nodes, N)
    t_eval = bary.res_eval_grid.astype(float)

    Y_star = pyo_model.pyomo_var_to_numpy(pyo_model.model.Y_star, (N, pyo_model.state_dim))
    Ws = pyo_model.convert_weights()
    bs = pyo_model.convert_biases()

    ode_lhs = D @ Y_star
    Y_eval  = L @ Y_star
    nn_out  = np.array([pyo_model.nn_prediction(0, Y_eval[i], Ws, bs) for i in range(num_eval_nodes)])

    return t_eval, ode_lhs - nn_out


#-----------------------------------PLOTTING--------------------------------------

num_eval_nodes = 5000

t_cont_dc,    res_train_dc    = compute_continuous_residual(pyo_model_dc,    num_eval_nodes)
t_cont_irrdc, res_train_irrdc = compute_continuous_residual(pyo_model_irrdc, num_eval_nodes)

skip_plot_points = 50
t_plot_dc     = t_cont_dc[skip_plot_points:]     if len(t_cont_dc)    > skip_plot_points else t_cont_dc
res_plot_dc   = res_train_dc[skip_plot_points:]  if len(res_train_dc) > skip_plot_points else res_train_dc
t_plot_irrdc  = t_cont_irrdc[skip_plot_points:]  if len(t_cont_irrdc) > skip_plot_points else t_cont_irrdc
res_plot_irrdc = res_train_irrdc[skip_plot_points:] if len(res_train_irrdc) > skip_plot_points else res_train_irrdc

zoom_t_min, zoom_t_max = 3.5, 4.5
y_label = r'$|\mathbf{r}(t)|$'
box_color = 'dimgray'
box_style = ':'
box_lw = 1.1

fig, axes = plt.subplots(
    2, 2,
    figsize=(15, 8),
    gridspec_kw={'width_ratios': [3.5, 1.4], 'wspace': 0.25, 'hspace': 0.3}
)
state_names = ['Displacement', 'Velocity']

for state_idx, state_name in enumerate(state_names):
    ax_full = axes[state_idx, 0]
    ax_zoom = axes[state_idx, 1]

    y_dc    = np.abs(res_plot_dc[:, state_idx])
    y_irrdc = np.abs(res_plot_irrdc[:, state_idx])

    # Full view (left)
    ax_full.plot(t_plot_dc,    y_dc,    color='firebrick',   linewidth=1.0, label='DC')
    ax_full.plot(t_plot_irrdc, y_irrdc, color='forestgreen', linewidth=1.0,
                 label=r'IRR-DC ($\rho=$' + f'{pyo_model_irrdc.rho_reg})')
    ax_full.set_title(f'{state_name}')
    ax_full.set_xlabel('t')
    ax_full.set_ylabel(y_label)
    ax_full.legend(loc='upper left', fontsize=8)

    # Zoomed view (right)
    ax_zoom.plot(t_plot_dc,    y_dc,    color='firebrick',   linewidth=1.0)
    ax_zoom.plot(t_plot_irrdc, y_irrdc, color='forestgreen', linewidth=1.0)
    ax_zoom.set_xlim(zoom_t_min, zoom_t_max)

    zoom_mask_dc    = (t_plot_dc    >= zoom_t_min) & (t_plot_dc    <= zoom_t_max)
    zoom_mask_irrdc = (t_plot_irrdc >= zoom_t_min) & (t_plot_irrdc <= zoom_t_max)
    y_zoom = np.concatenate([y_dc[zoom_mask_dc], y_irrdc[zoom_mask_irrdc]])

    if y_zoom.size > 0:
        y_min, y_max = np.min(y_zoom), np.max(y_zoom)
        pad = 0.05 * (y_max - y_min) if y_max > y_min else 1e-12
        y_low  = max(0.0, y_min - pad)
        y_high = y_max + pad
        ax_zoom.set_ylim(y_low, y_high)

        zoom_box = Rectangle(
            (zoom_t_min, y_low),
            zoom_t_max - zoom_t_min,
            y_high - y_low,
            fill=False, edgecolor=box_color, linestyle=box_style, linewidth=box_lw
        )
        ax_full.add_patch(zoom_box)

        con_top = ConnectionPatch(
            xyA=(zoom_t_max, y_high), coordsA=ax_full.transData,
            xyB=(0.0, 1.0),           coordsB=ax_zoom.transAxes,
            linestyle=box_style, color=box_color, linewidth=box_lw
        )
        con_bot = ConnectionPatch(
            xyA=(zoom_t_max, y_low), coordsA=ax_full.transData,
            xyB=(0.0, 0.0),          coordsB=ax_zoom.transAxes,
            linestyle=box_style, color=box_color, linewidth=box_lw
        )
        fig.add_artist(con_top)
        fig.add_artist(con_bot)

    ax_zoom.set_xlabel('t')
    ax_zoom.set_ylabel(y_label)

fig.suptitle(r'ODE Residual in Training Domain, $\mathbf{r}(t) = \dot{\mathbf{Y}}(t) - \mathbf{F}_{\boldsymbol{\theta}}(\mathbf{Y}(t))$')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from src.direct_collocation import BarycentricInterpolation
#       2 from matplotlib.patches import Rectangle, ConnectionPatch
#       4 #--------------------------RESIDUAL COMPUTATION FUNCS-----------------------------
#
# ModuleNotFoundError: No module named 'src.direct_collocation'
